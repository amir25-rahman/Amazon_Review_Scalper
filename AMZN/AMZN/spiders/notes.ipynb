# %%
#cd C:\Users\Null\Desktop\python_tur\AMZN\AMZN\spiders
#scrapy genspider amzn_scalp amazon.com
#scrapy runspider amzn_scalp.py
#scrapy runspider amzn_scalp.py -o articles.csv -t csv

# %%
# pip install scrapy_proxy_pool

# %%
#pip install scrapy-user-agents
#pip install Scrapy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the 'c:\Users\Null\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
